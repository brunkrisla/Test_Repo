# %%
import coiled
import dask 
import pandas as pd

# %%
#Link to coiled.Cluster() documentation: https://docs.coiled.io/user_guide/clusters/api.html

cluster = coiled.Cluster(n_workers=10)
client = cluster.get_client()
client
#cluster.scale(15) # Optional: scale the cluster to 15 workers
#cluster.adapt(minimum=10, maximum =30) # Optional: let dask adapt the cluster size to meet demands of workflow between 10 and 30 workers
# Out:
# [2025-11-22 15:54:19,599][INFO    ][coiled] Fetching latest package priorities...
# [2025-11-22 15:54:19,601][INFO    ][coiled.package_sync] Resolving your local test-repo-VMNSawPo-py3.13 Python environment...
# [2025-11-22 15:54:19,812][INFO    ][coiled.package_sync] Scanning 110 python packages...
# [2025-11-22 15:54:19,957][INFO    ][coiled] Running pip check...
# [2025-11-22 15:54:20,962][INFO    ][coiled] Validating environment...
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [2025-11-22 15:54:24,076][INFO    ][coiled] Requesting package sync build...
# ...

# %%
client
# Out:
# <Client: 'tls://10.0.81.9:8786' processes=10 threads=40, memory=143.42 GiB>

# %%
df = dask.datasets.timeseries("2000", "2005", partition_freq="2W").persist()

# %%
df['z'] = df['x'] + df['y']
df['first_char'] = df['name'].str[0]
df.head(10)

# %%
cluster.shutdown()
client.close()
# Out:
# [2025-11-22 16:08:48,173][INFO    ][coiled] Cluster 1279450 deleted successfully.
